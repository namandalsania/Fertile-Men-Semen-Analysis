# %% [markdown]
# ## Importing Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from IPython import get_ipython
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('Fertile_Man_2020.csv')

# %%
data.head()
# Out:
#            PI Semen Volume (ml) Sperm Concentration (106/ml)  \
# 0  Aboutorabi               3.2                         27.0
# 1  Aboutorabi               0.8                        136.0
# 2  Aboutorabi               2.0                         71.0
# 3  Aboutorabi               1.0                         35.0
# 4  Aboutorabi               2.0                         46.0
#
#   Total Number (106) Total Motility (%) Progressive Motility (%)  \
# 0               86.4                 35                       20
# 1              108.8                 47                       35
# 2              142.0                 49                       42
# 3               35.0                 50                       28
# 4               92.0                 51                       28
#
#   Non-progressive Motility (%) Immotile Spermatozoa (%) Vitality (%)  \
# 0                           15                       65    NO RESULT
# 1                           12                       53    NO RESULT
# 2                            7                       51    NO RESULT
# 3                           22                       50    NO RESULT
# 4                           33                       49    NO RESULT
#
#   Normal Forms (%)
# 0        NO RESULT
# 1        NO RESULT
# 2        NO RESULT
# 3        NO RESULT
# 4        NO RESULT

# %%
data.tail()
# Out:
#         PI Semen Volume (ml) Sperm Concentration (106/ml) Total Number (106)  \
# 3584  Tang               1.7                         23.0               39.1
# 3585  Tang               2.5                        110.0              275.0
# 3586  Tang               2.0                        109.0              218.0
# 3587  Tang               6.2                         96.0              595.2
# 3588  Tang               3.0                         36.0              108.0
#
#      Total Motility (%) Progressive Motility (%) Non-progressive Motility (%)  \
# 3584                 53                       52                            1
# 3585                 66                       66                            0
# 3586                 64                       44                           20
# 3587                 39                       29                           10
# 3588                 54                       38                           16
#
#      Immotile Spermatozoa (%) Vitality (%) Normal Forms (%)
# 3584                NO RESULT           82               25
# 3585                NO RESULT           95               30
# 3586                       36    NO RESULT               11
# 3587                       61    NO RESULT                7
# 3588                       46    NO RESULT               11

# %%
data.shape
# Out:
# (3589, 10)

# %%
data.columns
# Out:
# Index(['PI', 'Semen Volume (ml)', 'Sperm Concentration (106/ml)',
#        'Total Number (106)', 'Total Motility (%)', 'Progressive Motility (%)',
#        'Non-progressive Motility (%)', 'Immotile Spermatozoa (%)',
#        'Vitality (%)', 'Normal Forms (%)'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning and Pre-processing

# %%
data.duplicated().sum()
# Out:
# 220

# %%
data = data.drop_duplicates()

# %%
data.isnull().sum()
# Out:
# PI                              0
# Semen Volume (ml)               0
# Sperm Concentration (106/ml)    0
# Total Number (106)              0
# Total Motility (%)              0
# Progressive Motility (%)        0
# Non-progressive Motility (%)    0
# Immotile Spermatozoa (%)        0
# Vitality (%)                    0
# Normal Forms (%)                0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3369 entries, 0 to 3588
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   PI                            3369 non-null   object
#  1   Semen Volume (ml)             3369 non-null   object
#  2   Sperm Concentration (106/ml)  3369 non-null   object
#  3   Total Number (106)            3369 non-null   object
#  4   Total Motility (%)            3369 non-null   object
#  5   Progressive Motility (%)      3369 non-null   object
#  6   Non-progressive Motility (%)  3369 non-null   object
#  7   Immotile Spermatozoa (%)      3369 non-null   object
#  8   Vitality (%)                  3369 non-null   object
#  9   Normal Forms (%)              3369 non-null   object
# dtypes: object(10)
# memory usage: 289.5+ KB

# %%
data.nunique()
# Out:
# PI                                10
# Semen Volume (ml)                 97
# Sperm Concentration (106/ml)     644
# Total Number (106)              1652
# Total Motility (%)                88
# Progressive Motility (%)          91
# Non-progressive Motility (%)      52
# Immotile Spermatozoa (%)          85
# Vitality (%)                      66
# Normal Forms (%)                  67
# dtype: int64

# %%
data['PI'].unique()
# Out:
# array(['Aboutorabi', 'Auger', 'Baker', 'Evgeni', 'Haugen', 'Jensen',
#        'Lotti', 'Swan', 'Zedan', 'Tang'], dtype=object)

# %%
data['PI'].value_counts()
# Out:
# Tang          1050
# Auger          826
# Swan           487
# Baker          206
# Jensen         199
# Zedan          170
# Aboutorabi     168
# Lotti          105
# Haugen          82
# Evgeni          76
# Name: PI, dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
plt.figure(figsize=(15, 6))
sns.countplot('PI', data=data, palette='hls')
plt.xticks(rotation=90)
plt.show()

# %%
data.columns
# Out:
# Index(['PI', 'Semen Volume (ml)', 'Sperm Concentration (106/ml)',
#        'Total Number (106)', 'Total Motility (%)', 'Progressive Motility (%)',
#        'Non-progressive Motility (%)', 'Immotile Spermatozoa (%)',
#        'Vitality (%)', 'Normal Forms (%)'],
#       dtype='object')

# %%
data_new = data[['Semen Volume (ml)', 'Sperm Concentration (106/ml)',
'Total Number (106)', 'Total Motility (%)', 'Progressive Motility (%)',
'Non-progressive Motility (%)', 'Immotile Spermatozoa (%)',
'Vitality (%)', 'Normal Forms (%)']]

# %%
data_new.head()
# Out:
#   Semen Volume (ml) Sperm Concentration (106/ml) Total Number (106)  \
# 0               3.2                         27.0               86.4
# 1               0.8                        136.0              108.8
# 2               2.0                         71.0              142.0
# 3               1.0                         35.0               35.0
# 4               2.0                         46.0               92.0
#
#   Total Motility (%) Progressive Motility (%) Non-progressive Motility (%)  \
# 0                 35                       20                           15
# 1                 47                       35                           12
# 2                 49                       42                            7
# 3                 50                       28                           22
# 4                 51                       28                           33
#
#   Immotile Spermatozoa (%) Vitality (%) Normal Forms (%)
# 0                       65    NO RESULT        NO RESULT
# 1                       53    NO RESULT        NO RESULT
# 2                       51    NO RESULT        NO RESULT
# 3                       50    NO RESULT        NO RESULT
# 4                       49    NO RESULT        NO RESULT

# %%
data_new = data_new.replace({'Semen Volume (ml)': {'NO RESULT': 0}})
data_new = data_new.replace({'Sperm Concentration (106/ml)': {'NO RESULT': 0}})
data_new = data_new.replace({'Total Number (106)': {'NO RESULT': 0}})
data_new = data_new.replace({'Total Motility (%)': {'NO RESULT': 0}})
data_new = data_new.replace({'Progressive Motility (%)': {'NO RESULT': 0}})
data_new = data_new.replace({'Non-progressive Motility (%)': {'NO RESULT': 0}})
data_new = data_new.replace({'Immotile Spermatozoa (%)': {'NO RESULT': 0}})
data_new = data_new.replace({'Normal Forms (%)': {'NO RESULT': 0}})
data_new = data_new.replace({'Vitality (%)': {'NO RESULT': 0}})

# %%
data_new
# Out:
#      Semen Volume (ml) Sperm Concentration (106/ml) Total Number (106)  \
# 0                  3.2                         27.0               86.4
# 1                  0.8                        136.0              108.8
# 2                  2.0                         71.0              142.0
# 3                  1.0                         35.0               35.0
# 4                  2.0                         46.0               92.0
# ...                ...                          ...                ...
# 3579               2.0                        115.0              230.0
# 3581               4.0                         22.0               88.0
# 3586               2.0                        109.0              218.0
# 3587               6.2                         96.0              595.2
# 3588               3.0                         36.0              108.0
#
#      Total Motility (%) Progressive Motility (%) Non-progressive Motility (%)  \
# 0                    35                       20                           15
# 1                    47                       35                           12
# 2                    49                       42                            7
# 3                    50                       28                           22
# 4                    51                       28                           33
# ...                 ...                      ...                          ...
# 3579                 79                       77                            2
# 3581                 35                       32                            3
# 3586                 64                       44                           20
# 3587                 39                       29                           10
# 3588                 54                       38                           16
#
#      Immotile Spermatozoa (%) Vitality (%) Normal Forms (%)
# 0                          65            0                0
# 1                          53            0                0
# 2                          51            0                0
# 3                          50            0                0
# 4                          49            0                0
# ...                       ...          ...              ...
# 3579                        0           82               25
# 3581                        0           38               23
# 3586                       36            0               11
# 3587                       61            0                7
# 3588                       46            0               11
#
# [3369 rows x 9 columns]

# %%
for i in data_new.columns:
    data_new[i] = data_new[i].astype(float)

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3369 entries, 0 to 3588
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Semen Volume (ml)             3369 non-null   float64
#  1   Sperm Concentration (106/ml)  3369 non-null   float64
#  2   Total Number (106)            3369 non-null   float64
#  3   Total Motility (%)            3369 non-null   float64
#  4   Progressive Motility (%)      3369 non-null   float64
#  5   Non-progressive Motility (%)  3369 non-null   float64
#  6   Immotile Spermatozoa (%)      3369 non-null   float64
#  7   Vitality (%)                  3369 non-null   float64
#  8   Normal Forms (%)              3369 non-null   float64
# dtypes: float64(9)
# memory usage: 392.2 KB

# %%
for i in data_new.columns:
    plt.figure(figsize=(15, 6))
    sns.distplot(data_new[i])
    plt.xticks(rotation=90)
    plt.show()

# %%
for i in data_new.columns:
    plt.figure(figsize=(15, 6))
    sns.boxplot(data_new[i])
    plt.xticks(rotation=90)
    plt.show()

# %%
for i in data_new.columns:
    plt.figure(figsize=(15, 6))
    sns.violinplot(data_new[i])
    plt.xticks(rotation=90)
    plt.show()

# %%
corrmat = data_new.corr()
corrmat
# Out:
#                               Semen Volume (ml)  Sperm Concentration (106/ml)  \
# Semen Volume (ml)                      1.000000                     -0.132747
# Sperm Concentration (106/ml)          -0.132747                      1.000000
# Total Number (106)                     0.394834                      0.762657
# Total Motility (%)                     0.003056                      0.070431
# Progressive Motility (%)               0.093729                      0.082049
# Non-progressive Motility (%)          -0.163921                     -0.016940
# Immotile Spermatozoa (%)               0.095168                      0.034547
# Vitality (%)                          -0.156211                     -0.170896
# Normal Forms (%)                       0.002695                      0.109208
#
#                               Total Number (106)  Total Motility (%)  \
# Semen Volume (ml)                       0.394834            0.003056
# Sperm Concentration (106/ml)            0.762657            0.070431
# Total Number (106)                      1.000000            0.056822
# Total Motility (%)                      0.056822            1.000000
# Progressive Motility (%)                0.127535            0.772534
# Non-progressive Motility (%)           -0.116299            0.377100
# Immotile Spermatozoa (%)                0.070889           -0.400565
# Vitality (%)                           -0.210887            0.364078
# Normal Forms (%)                        0.117101           -0.226283
#
#                               Progressive Motility (%)  \
# Semen Volume (ml)                             0.093729
# Sperm Concentration (106/ml)                  0.082049
# Total Number (106)                            0.127535
# Total Motility (%)                            0.772534
# Progressive Motility (%)                      1.000000
# Non-progressive Motility (%)                 -0.077893
# Immotile Spermatozoa (%)                     -0.388460
# Vitality (%)                                  0.324613
# Normal Forms (%)                             -0.237217
#
#                               Non-progressive Motility (%)  \
# Semen Volume (ml)                                -0.163921
# Sperm Concentration (106/ml)                     -0.016940
# Total Number (106)                               -0.116299
# Total Motility (%)                                0.377100
# Progressive Motility (%)                         -0.077893
# Non-progressive Motility (%)                      1.000000
# Immotile Spermatozoa (%)                         -0.089031
# Vitality (%)                                      0.148656
# Normal Forms (%)                                 -0.290616
#
#                               Immotile Spermatozoa (%)  Vitality (%)  \
# Semen Volume (ml)                             0.095168     -0.156211
# Sperm Concentration (106/ml)                  0.034547     -0.170896
# Total Number (106)                            0.070889     -0.210887
# Total Motility (%)                           -0.400565      0.364078
# Progressive Motility (%)                     -0.388460      0.324613
# Non-progressive Motility (%)                 -0.089031      0.148656
# Immotile Spermatozoa (%)                      1.000000     -0.526984
# Vitality (%)                                 -0.526984      1.000000
# Normal Forms (%)                             -0.174062     -0.065345
#
#                               Normal Forms (%)
# Semen Volume (ml)                     0.002695
# Sperm Concentration (106/ml)          0.109208
# Total Number (106)                    0.117101
# Total Motility (%)                   -0.226283
# Progressive Motility (%)             -0.237217
# Non-progressive Motility (%)         -0.290616
# Immotile Spermatozoa (%)             -0.174062
# Vitality (%)                         -0.065345
# Normal Forms (%)                      1.000000

# %%
cmap = sns.diverging_palette(260, -10, s=50, l=75, n=6, as_cmap=True)
plt.subplots(figsize=(18, 18))
sns.heatmap(corrmat, cmap=cmap, annot=True, square=True)
plt.show()
